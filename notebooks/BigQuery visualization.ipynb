# %%
# %load_ext google.cloud.bigquery

# %%
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %%
# %%bigquery queried_df
# SELECT
#     timestamp,
#     volume,
#     average
# FROM `tradesponder.blotter.ESZ9_334144679`

# %%
df = queried_df

# %%
df = df.set_index('timestamp')
df
# Out:
#                            volume  average
# timestamp
# 2019-12-08 23:31:40+00:00      53  3147.00
# 2019-12-08 23:31:45+00:00       1  3147.00
# 2019-12-08 23:31:50+00:00       0  3147.00
# 2019-12-08 23:31:55+00:00       9  3147.00
# 2019-12-08 23:32:00+00:00       0  3147.00
# ...                           ...      ...
# 2019-12-08 23:25:25+00:00       3  3147.25
# 2019-12-08 23:25:30+00:00       6  3147.25
# 2019-12-08 23:25:35+00:00       0  3147.25
# 2019-12-08 23:25:40+00:00      14  3147.25
# 2019-12-08 23:25:45+00:00       4  3147.25
#
# [420 rows x 2 columns]

# %%
df[['average']].plot()
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S', tz=df.index.tz))

# %%
df[['volume']].plot()
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S', tz=df.index.tz))
